# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-88e2ece8-58ba-4360-b341-9a01dbe2e0e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88e2ece8-58ba-4360-b341-9a01dbe2e0e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
xls = pd.ExcelFile('Data Source 2.xlsx',engine='openpyxl')

print(xls.sheet_names)
# Out:
# ['Domestic Sales ', 'Retail-Aug 25', 'Festive Data']

# %% [markdown]
# ANALYSING DOMESTIC SALES DATA

# %%
df = pd.read_excel('Data Source 2.xlsx',sheet_name = 'Domestic Sales ', engine='openpyxl')
df.head()
# Out:
#               Category   2019-20   2020-21   2021-22   2022-23    2023-24  \
# 0   Passenger Vehicles   2773519   2711457   3069523   3890114  42 18,750
# 1  Commercial Vehicles    717593    568559    716566    962468     968770
# 2       Three Wheelers    637065    219446    261385    488768     694801
# 3         Two Wheelers  17416432  15120783  13570008  15862771   17974365
# 4         Quadricycles       942       -12       124       725        725
#
#     2024-25  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0   4301848         NaN         NaN         NaN
# 1    956671         NaN         NaN         NaN
# 2    741420         NaN         NaN         NaN
# 3  19607332         NaN         NaN         NaN
# 4       120         NaN         NaN         NaN
#
#                                          Unnamed: 10
# 0                                             SOURCE
# 1  FADA Research - monthly retail reports (https:...
# 2  SIAM - vehicle production and sales reports (h...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category     6 non-null      object
#  1   2019-20      6 non-null      int64
#  2   2020-21      6 non-null      int64
#  3   2021-22      6 non-null      int64
#  4   2022-23      6 non-null      int64
#  5   2023-24      6 non-null      object
#  6   2024-25      6 non-null      int64
#  7   Unnamed: 7   0 non-null      float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  3 non-null      object
# dtypes: float64(3), int64(5), object(3)
# memory usage: 660.0+ bytes

# %%
df.dropna(axis =1,inplace=True)

# %%
df.head(6)
# Out:
#               Category   2019-20   2020-21   2021-22   2022-23    2023-24  \
# 0   Passenger Vehicles   2773519   2711457   3069523   3890114  42 18,750
# 1  Commercial Vehicles    717593    568559    716566    962468     968770
# 2       Three Wheelers    637065    219446    261385    488768     694801
# 3         Two Wheelers  17416432  15120783  13570008  15862771   17974365
# 4         Quadricycles       942       -12       124       725        725
# 5          Grand Total  21545551  18620233  17617606  21204846   23857411
#
#     2024-25
# 0   4301848
# 1    956671
# 2    741420
# 3  19607332
# 4       120
# 5  25607391

# %%
df.columns
# Out:
# Index(['Category', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24',
#        '2024-25'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of               Category   2019-20   2020-21   2021-22   2022-23    2023-24  \
# 0   Passenger Vehicles   2773519   2711457   3069523   3890114  42 18,750
# 1  Commercial Vehicles    717593    568559    716566    962468     968770
# 2       Three Wheelers    637065    219446    261385    488768     694801
# 3         Two Wheelers  17416432  15120783  13570008  15862771   17974365
# 4         Quadricycles       942       -12       124       725        725
# 5          Grand Total  21545551  18620233  17617606  21204846   23857411
#
#     2024-25
# 0   4301848
# 1    956671
# 2    741420
# 3  19607332
# 4       120
# 5  25607391  >

# %%
df.columns
# Out:
# Index(['Category', '2019-20', '2020-21', '2021-22', '2022-23', '2023-24',
#        '2024-25'],
#       dtype='object')

# %%
year_cols = ['2019-20', '2020-21', '2021-22', '2022-23', '2023-24','2024-25']

grand_total = df[df['Category'].str.lower() == 'grand total']

sales = grand_total[year_cols].values.flatten()


plt.figure(figsize=(6,2))



plt.plot(year_cols,sales)

plt.ylabel('Year')
plt.xlabel('Sales')
plt.title("Combined Sales throughout the Years")
plt.xticks(rotation=45)

plt.show()

# %%
year_cols = ['2019-20', '2020-21', '2021-22', '2022-23', '2023-24','2024-25']

for col in year_cols:
        df[col] = df[col].astype(str).str.replace(',', '').str.replace(' ', '').astype(float)



df['Total_Sales'] = df[year_cols].sum(axis=1)

df_Cat=df[df['Category'].str.lower() != 'grand total']

plt.figure(figsize=(6,2))

sns.barplot(x='Category',y='Total_Sales',data = df_Cat)


plt.title('Sales by Category across years')
plt.ylabel('Sales')
plt.title("All Categories Sales throughout the Years")
plt.xticks(rotation=45)
plt.ylabel('Total Sales')
plt.show()

# %%
print(xls.sheet_names)
# Out:
# ['Domestic Sales ', 'Retail-Aug 25', 'Festive Data']

# %%
df =pd.read_excel('Data Source 2.xlsx',sheet_name='Retail-Aug 25',engine='openpyxl')
df.head(20)
# Out:
#                        CATEGORY   Aug'25  July'25   Aug'24    MoM%    YoY%
# 0                            2W  1373675  1355504  1344380  0.0134  0.0218
# 1                            3W   103105   111426   105493 -0.0747 -0.0226
# 2               - E-RICKSHAW(P)    36969    39798    44346 -0.0711 -0.1664
# 3    - E-RICKSHAW WITH CART (G)     6213     6813     4396 -0.0881  0.4133
# 4       - THREE-WHEELER (GOODS)     9697     9862     8651 -0.0167  0.1209
# 5   - THREE-WHEELER (PASSENGER)    50100    54861    48012 -0.0868  0.0435
# 6    - THREE-WHEELER (PERSONAL)      126       92       88  0.3696  0.4318
# 7                            PV   323256   328613   320291 -0.0163  0.0093
# 8                          TRAC    85215    88722    65477 -0.0395  0.3014
# 9                            CE     3704     3509     5036  0.0556 -0.2645
# 10                           CV    75592    76439    69635 -0.0111  0.0855
# ...

# %%
df.columns
# Out:
# Index(['CATEGORY', 'Aug'25', 'July'25', 'Aug'24', 'MoM%', 'YoY%'], dtype='object')

# %%
df.plot(x='CATEGORY',
 y= ["Aug'25","Aug'24"],
        kind='bar',
        figsize=(10,3),
        title='Vehicle Retail Data Aug 24 vs Aug 25'

)
plt.xticks(rotation=45)


plt.ylabel('Units SOld')
plt.show()

# %%
df.columns
# Out:
# Index(['CATEGORY', 'Aug'25', 'July'25', 'Aug'24', 'MoM%', 'YoY%'], dtype='object')

# %%
df.plot(x='CATEGORY',
 y= ["July'25","Aug'25"],
        kind='bar',
        figsize=(10,3),
        title='Vehicle Retail Data July 25 vs Aug 25'

)
plt.xticks(rotation=45)


plt.ylabel('Units SOld')
plt.show()

# %%
df.columns
# Out:
# Index(['CATEGORY', 'Aug'25', 'July'25', 'Aug'24', 'MoM%', 'YoY%'], dtype='object')

# %%
df.plot(
    x='CATEGORY',
    y=["MoM%", "YoY%"],
    kind='line',
    marker='o',
    figsize=(10,7),
    title="MoM% vs YoY% by Category (Aug'25)",
)
plt.axhline(0, color='gray', linestyle='--')
plt.ylabel("Percentage Change (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #FESTIVE TRENDS ANALYSIS (Growth between 23-24)

# %%
print(xls.sheet_names)
# Out:
# ['Domestic Sales ', 'Retail-Aug 25', 'Festive Data']

# %%
df =pd.read_excel('Data Source 2.xlsx',sheet_name='Festive Data',engine='openpyxl')
df.head(20)
# Out:
#   CATEGORY  Festive'24  Festive'23  Growth %
# 0       2W     3311325     2910141    0.1379
# 1       3W      159960      149764    0.0681
# 2       CV      128738      127436    0.0102
# 3       PV      603009      563059    0.0710
# 4     TRAC       85216       86640   -0.0164
# 5    Total     4288248     3837040    0.1176

# %%
df.columns
# Out:
# Index(['CATEGORY', 'Festive'24', 'Festive'23', 'Growth %'], dtype='object')

# %%
df.plot(
    x ='CATEGORY',
    y= ["Festive'24", "Festive'23"],
    kind ='bar',
    figsize=(5,4)

)

plt.title('Festive Sales for 2023 and 2024')
plt.ylabel('Units Sold')
plt.xticks(rotation=0)

plt.show()

# %%
df.columns
# Out:
# Index(['CATEGORY', 'Festive'24', 'Festive'23', 'Growth %'], dtype='object')

# %%
df.head(8)
# Out:
#   CATEGORY  Festive'24  Festive'23  Growth %
# 0       2W     3311325     2910141    0.1379
# 1       3W      159960      149764    0.0681
# 2       CV      128738      127436    0.0102
# 3       PV      603009      563059    0.0710
# 4     TRAC       85216       86640   -0.0164
# 5    Total     4288248     3837040    0.1176

# %%
df.plot(
    x='CATEGORY',
    y=["Growth %"],
    kind='line',
    figsize=(6,4)
)

plt.ylabel('Percent Change')
plt.title('Growth% across all categories')

plt.xticks(rotation=45)
plt.show()
